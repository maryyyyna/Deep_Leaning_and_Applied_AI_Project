# %% [markdown]
# # Deep Learning and Applied AI (DLAI) Project: **Fine-Tuning a LLM on Neapolitan Dialect**
#
# # Part III: Performance Evaluation
#
# ### Author: Aur Marina Iuliana, 1809715

# %% [markdown]
# # 1. Import Libraries

# %%
# !pip install transformers torch peft datasets evaluate trl bitsandbytes nltk rouge-score bert-score

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import torch
from transformers import AutoModelForCausalLM, AutoTokenizer, pipeline
from transformers import Trainer, TrainingArguments, DataCollatorForLanguageModeling

from trl import SFTConfig, SFTTrainer
from nltk.translate.bleu_score import sentence_bleu
from rouge_score import rouge_scorer
from bert_score import score as bert_score

import numpy as np
import pandas as pd
import os

import matplotlib.pyplot as plt
import seaborn as sns
import json
import glob

from transformers import EarlyStoppingCallback

from datasets import Dataset, load_dataset
from sklearn.model_selection import train_test_split

from tqdm import tqdm
from peft import get_peft_model, LoraConfig, TaskType
import re

import warnings
warnings.simplefilter(action='ignore')

# %%
# !huggingface-cli login
# Out:
#     _|    _|  _|    _|    _|_|_|    _|_|_|  _|_|_|  _|      _|    _|_|_|      _|_|_|_|    _|_|      _|_|_|  _|_|_|_|
#     _|    _|  _|    _|  _|        _|          _|    _|_|    _|  _|            _|        _|    _|  _|        _|
#     _|_|_|_|  _|    _|  _|  _|_|  _|  _|_|    _|    _|  _|  _|  _|  _|_|      _|_|_|    _|_|_|_|  _|        _|_|_|
#     _|    _|  _|    _|  _|    _|  _|    _|    _|    _|    _|_|  _|    _|      _|        _|    _|  _|        _|
#     _|    _|    _|_|      _|_|_|    _|_|_|  _|_|_|  _|      _|    _|_|_|      _|        _|    _|    _|_|_|  _|_|_|_|
#
#     To login, `huggingface_hub` requires a token generated from https://huggingface.co/settings/tokens .
# Enter your token (input will not be visible):
# Add token as git credential? (Y/n) n
# Token is valid (permission: read).
# Your token has been saved to /root/.cache/huggingface/token
# Login successful

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
device
# Out:
# device(type='cuda')

# %%
if torch.cuda.is_available():
    gpu_name = torch.cuda.get_device_name(0)
    print("GPU:", gpu_name)
# Out:
# GPU: Tesla T4

# %% [markdown]
# # 2. Import and Split Data

# %%
# Load the dataset and split it into train, validation and test sets:
# 70% of the data will be used for training
# 10% of the data for validation
# 20% of the data for testing

final_dataset = load_dataset('csv', data_files='/content/sample_data/nap_dialect.csv', split = ['train[:70%]', 'train[70%:80%]', 'train[80%:]'])

final_dataset = {
    "train": final_dataset[0],
    "validation": final_dataset[1],
    "test": final_dataset[2]
}

final_dataset
# Out:
# Generating train split: 0 examples [00:00, ? examples/s]
# {'train': Dataset({
#      features: ['recipe', 'prompt', 'content'],
#      num_rows: 8855
#  }),
#  'validation': Dataset({
#      features: ['recipe', 'prompt', 'content'],
#      num_rows: 1265
#  }),
#  'test': Dataset({
#      features: ['recipe', 'prompt', 'content'],
#      num_rows: 2530
#  })}

# %% [markdown]
# # 3. Modelling

# %% [markdown]
# ## 3.1 Vanilla Llama Model

# %%
torch.random.manual_seed(0)
model_name = "meta-llama/Llama-3.2-1B"

vanilla_model = AutoModelForCausalLM.from_pretrained(
    model_name,
    device_map = "auto",
    torch_dtype = "auto",
    trust_remote_code = True,
)

vanilla_tokenizer = AutoTokenizer.from_pretrained(model_name)
vanilla_tokenizer.pad_token = vanilla_tokenizer.eos_token

# %% [markdown]
# ## 3.2 Fine-Tuned Llama Model

# %%
fine_tuned_model = AutoModelForCausalLM.from_pretrained("/content/drive/MyDrive/Colab Notebooks/DLAI/fine_tuned_LLM_model").to(device)
fine_tuned_tokenizer = AutoTokenizer.from_pretrained("/content/drive/MyDrive/Colab Notebooks/DLAI/fine_tuned_LLM_model")

# %% [markdown]
# # 4. Performance Evaluation

# %% [markdown]
# ## 4.1 Perplexity

# %%
def compute_ppl(model, encodings, max_length = 128, stride = 512, device = "cuda"):
  '''
  Compute the perplexity of a given model using the provided encodings.
  '''
  if max_length is None:
      max_length = model.config.max_length

  seq_len = encodings.input_ids.size(1)
  nlls = []
  prev_end_loc = 0

  for begin_loc in tqdm(range(0, seq_len, stride)):
    end_loc = min(begin_loc + max_length, seq_len)
    trg_len = end_loc - prev_end_loc  # May differ from stride on the last loop
    input_ids = encodings.input_ids[:, begin_loc:end_loc].to(device)
    target_ids = input_ids.clone()
    target_ids[:, :-trg_len] = -100  # Only consider trg_len labels

    with torch.no_grad():
      outputs = model(input_ids, labels=target_ids)

      # Loss is calculated using CrossEntropyLoss which averages over valid labels
      neg_log_likelihood = outputs.loss

      nlls.append(neg_log_likelihood)
      prev_end_loc = end_loc
      if end_loc == seq_len:
        break

  ppl = torch.exp(torch.stack(nlls).mean())
  return ppl

# %%
# Prepare the test data
test_set = final_dataset['test']

vanilla_encodings = vanilla_tokenizer("\n\n".join(test_set["recipe"]), return_tensors = "pt", truncation = True, max_length = 131072).to(device)
fine_tuned_encodings = fine_tuned_tokenizer("\n\n".join(test_set["recipe"]), return_tensors = "pt", truncation = True, max_length = 131072).to(device)

# %%
fine_tuned_ppl = compute_ppl(fine_tuned_model, fine_tuned_encodings)

print(f"Fine-tuned model perplexity: {fine_tuned_ppl}")
# Out:
# 100%|██████████| 256/256 [00:30<00:00,  8.28it/s]
# Fine-tuned model perplexity: 17.350080490112305

# %%
vanilla_ppl = compute_ppl(vanilla_model, vanilla_encodings)

print(f"Vanilla model perplexity: {vanilla_ppl}")
# Out:
# 100%|██████████| 256/256 [00:36<00:00,  7.06it/s]
# Vanilla model perplexity: 36.56854248046875

# %% [markdown]
# ## 4.2 BLEU, ROUGE and BERT Scores

# %%
def compute_scores(generated_responses, reference_texts):
  rouge = rouge_scorer.RougeScorer(['rouge1', 'rouge2', 'rougeL'], use_stemmer=True)
  results = []

  P, R, F1 = bert_score(generated_responses, reference_texts, lang = "it")

  for i, (gen_text, ref_text) in enumerate(zip(generated_responses, reference_texts)):
    # Compute BLEU Score
    bleu_score = sentence_bleu([ref_text.split()], gen_text.split())

    # Compute ROUGE Score
    rouge_scores = rouge.score(ref_text, gen_text)
    rouge1 = rouge_scores['rouge1'].fmeasure
    rouge2 = rouge_scores['rouge2'].fmeasure
    rougeL = rouge_scores['rougeL'].fmeasure

    # BERTScore
    bert_f1 = F1[i].item()

    # Save the results
    results.append({
        "bleu": bleu_score,
        "r1": rouge1,
        "r2": rouge2,
        "rl": rougeL,
        "bertscore": bert_f1
        })

  return results

# %%
def performance_evaluation(model, tokenizer, examples):
  model.generation_config.pad_token_id = tokenizer.pad_token_id

  total_bleu = 0
  total_rouge1 = 0
  total_rouge2 = 0
  total_rougeL = 0
  total_bert_f1 = 0

  num_examples = len(examples)

  for example in examples:
    prompt, expected_response = example['prompt'], example['content']
    inputs = tokenizer(prompt, return_tensors="pt").to(device)
    output = model.generate(**inputs, max_length=100)
    response = tokenizer.decode(output[0], skip_special_tokens=True)

    results = compute_scores([response], [expected_response])

    # Accumulate the scores
    total_bleu += results[0]['bleu']
    total_rouge1 += results[0]['r1']
    total_rouge2 += results[0]['r2']
    total_rougeL += results[0]['rl']
    total_bert_f1 += results[0]['bertscore']

  # Compute averages
  avg_bleu = total_bleu / num_examples
  avg_rouge1 = total_rouge1 / num_examples
  avg_rouge2 = total_rouge2 / num_examples
  avg_rougeL = total_rougeL / num_examples
  avg_bert_f1 = total_bert_f1 / num_examples

  return {
        'average_bleu': avg_bleu,
        'average_rouge1': avg_rouge1,
        'average_rouge2': avg_rouge2,
        'average_rougeL': avg_rougeL,
        'average_bert_f1': avg_bert_f1
    }

# %%
# Compute scores using Fine-Tuned Llama Model
examples = final_dataset['test'].select(range(50))

fine_tuned_results = performance_evaluation(fine_tuned_model, fine_tuned_tokenizer, examples)
fine_tuned_results
# Out:
# {'average_bleu': 0.00019290558429151344,
#  'average_rouge1': 0.08721816031878457,
#  'average_rouge2': 0.015992856028930233,
#  'average_rougeL': 0.0756294800844448,
#  'average_bert_f1': 0.5668070268630981}

# %%
# Compute scores using Vanilla Llama Model
vanilla_results = performance_evaluation(vanilla_model, vanilla_tokenizer, examples)
vanilla_results
# Out:
# {'average_bleu': 1.0712230592792708e-20,
#  'average_rouge1': 0.0544315744180519,
#  'average_rouge2': 0.01042936523827455,
#  'average_rougeL': 0.05106706829746666,
#  'average_bert_f1': 0.5473248547315598}

# %%
# Build the evaluation Dataframe
fine_tuned_results['perplexity'] = fine_tuned_ppl.item()
vanilla_results['perplexity'] = vanilla_ppl.item()

evaluation_df = pd.DataFrame([fine_tuned_results, vanilla_results], index=['Fine-Tuned Llama Model', 'Vanilla LLama Model'])
evaluation_df = evaluation_df.round(4)
evaluation_df
# Out:
#                         average_bleu  average_rouge1  average_rouge2  \
# Fine-Tuned Llama Model        0.0002          0.0872          0.0160
# Vanilla LLama Model           0.0000          0.0544          0.0104
#
#                         average_rougeL  average_bert_f1  perplexity
# Fine-Tuned Llama Model          0.0756           0.5668     17.3501
# Vanilla LLama Model             0.0511           0.5473     36.5685

# %% [markdown]
# # 5. Qualitative Assessment

# %%
def generate_response(model, tokenizer, examples):
  model.generation_config.pad_token_id = tokenizer.pad_token_id

  total_bleu = 0
  total_rouge1 = 0
  total_rouge2 = 0
  total_rougeL = 0
  total_bert_f1 = 0

  num_examples = len(examples)

  for example in examples:
    prompt, expected_response = example['prompt'], example['content']
    inputs = tokenizer(prompt, return_tensors="pt").to(device)
    output = model.generate(**inputs, max_length=100)
    response = tokenizer.decode(output[0], skip_special_tokens=True)

    # Compute_metrics
    results = compute_scores([response], [expected_response])

    print(f'Prompt: \n{prompt}\n')
    print(f'Fine-Tuned LLama Response: \n{response}\n')
    print(f'Expected Response: \n{expected_response}\n')
    print(f'BLEU Score: {results[0]["bleu"]}')
    print(f'ROUGE-1 Score: {results[0]["r1"]}')
    print(f'ROUGE-2 Score: {results[0]["r2"]}')
    print(f'ROUGE-L Score: {results[0]["rl"]}')
    print(f'BERTScore: {results[0]["bertscore"]}\n')
    print('------------------------------------------------\n')

# %%
examples_2 = final_dataset['test'].select(range(10, 13))

print("--- Qualitative Assessment using Fine-Tuned Llama Model --- \n ")
generate_response(fine_tuned_model, fine_tuned_tokenizer, examples_2)
# Out:
# --- Qualitative Assessment using Fine-Tuned Llama Model ---
#
# Prompt:
# Describe Marco Mengoni in Neapolitan dialect.
#
# Fine-Tuned LLama Response:
# Describe Marco Mengoni in Neapolitan dialect. Marco Mengoni (Napule, 14 'e nuvembre 1986) è nu cantante e attore napulitano. N'è d'ispirazione napulitana, 'o suo stile 'e canzone 'e canta è ca è 'e 'e "canzoni d'apule" (cante napulitano) e 'e "canzoni d
#
# Expected Response:
# Marco Mengoni (Ronciglione, 25 'e dicembre 1988) è nu cantante italiano. E' addevennuto famuso dint'o 2009, aroppo avè vincuto 'a terza serie 'e X Factor.
#
# BLEU Score: 1.6138666492065688e-78
# ROUGE-1 Score: 0.24242424242424243
# ROUGE-2 Score: 0.0625
# ROUGE-L Score: 0.24242424242424243
# BERTScore: 0.6966686844825745
#
# ------------------------------------------------
#
# Prompt:
# Describe Uocchie in Neapolitan dialect.
#
# Fine-Tuned LLama Response:
# Describe Uocchie in Neapolitan dialect. Endless summer in Neapolitan dialect. "A luna che si fa 'n nero" (The moon that's black) is the title of a Neapolitan dialect song, composed by Gaetano Catanese in 1958, and interpreted by Fausto Coppi. "A luna che si fa 'n nero" was a hit in Neapolitan dialect and in Neapolitan dialect music. "
#
# Expected Response:
# Gl uocchie, è gl òrgane de sènz prengepale de gl seštèma visive, ch'adda peglià nfremmaziune ngim’a quéll che seccède tòrn tòrn a iss attraviérz la luce.
# Gl uocchie umane (é de gl erganism seperiure) raccògl la luce che gl arriva de tutt attòrn a iss, ne règula la petènza attraviérz ne diaframma (l'iride), la fecalizza attraviérz ne seštèma regulábbele de lènd pe ne crià ne retratt ngim’a la rètena é gl cagna énd a na sèrie de segnale lèttrece ch’attraviérz gl niérv òtteche viéve mannate a gl cerviégl pe la štésa é la nderpretazione.
#
# BLEU Score: 5.136626626902174e-232
# ROUGE-1 Score: 0.08888888888888888
# ROUGE-2 Score: 0.0
# ROUGE-L Score: 0.06666666666666668
# BERTScore: 0.5302191376686096
#
# ------------------------------------------------
#
# Prompt:
# Describe Rescecature in Neapolitan dialect.
#
# Fine-Tuned LLama Response:
# Describe Rescecature in Neapolitan dialect. If you want to contribute, use the discussion page.
# Rescecature è nu comune 'e 1.039 crestiane d''a pruvincia 'e Vercelli.
# This page was last changed on 8 aprile 2018, at 10:28.
#
# Expected Response:
# Gle rescecature (IPA: [rǝʃǝkaˈtuːrǝ], sing.: rescecatore [rǝʃǝkaˈtoːrǝ]; Rodentia Bowdich, 1821) suó gl'òrdene de mammífere che tiéve gle cchiù ávete númmere de spèce mendevate (faštima no comme biomassa), abbraccènne circa gle 43% de tutte le spèce de mammífere ch'esištene a gle juorne d'uoje, cchiù avetetande taxa schembarze. Suó rrescite a avé tutte šte secciése faštima razie a gle fatte ca suó peccerigle, ca ze repredúcene cchiù vòte a gl'anne é a gle fatte ca rriéscene a rescecà é a chenzemà na ròssa varietà de magnà.
# De ss'òrdene fave parte spèce assá chenesciute é da gl'ariale ne muare spase, comm'a ratte, surge é ciurle, é pure spèce rare é da gl'ariale assá reštritte.
# Etemeleggía.
# Gle nome "rescecatore" ne vè da gle vèrbe latine "*rōsĭcare", che ne vè da "rōdĕre" (part. pass. "rōsus") "rescecà", ch'accènna a l'abbetúdene ch'acchemuna tutte gl'agnemale che fave parte de ss'òrdene.
#
# BLEU Score: 0
# ROUGE-1 Score: 0.03636363636363636
# ROUGE-2 Score: 0.0
# ROUGE-L Score: 0.03636363636363636
# BERTScore: 0.5572868585586548
#
# ------------------------------------------------

# %%
print("--- Qualitative Assessment using Vanilla Model --- \n")
generate_response(vanilla_model, vanilla_tokenizer, examples_2)
# Out:
# --- Qualitative Assessment using Vanilla Model ---
#
# Prompt:
# Describe Marco Mengoni in Neapolitan dialect.
#
# Fine-Tuned LLama Response:
# Describe Marco Mengoni in Neapolitan dialect. He is a 28 year old singer from Italy. He was born in 1987 in Rome, Italy. He is best known for his 2011 single “L'amore è un attimo”, which was the first Italian song to reach number one on the Eurovision Song Contest’s official chart. He has also released a number of singles and albums since 2010, including his debut studio album, Il segreto del mio
#
# Expected Response:
# Marco Mengoni (Ronciglione, 25 'e dicembre 1988) è nu cantante italiano. E' addevennuto famuso dint'o 2009, aroppo avè vincuto 'a terza serie 'e X Factor.
#
# BLEU Score: 2.305625093843957e-155
# ROUGE-1 Score: 0.0606060606060606
# ROUGE-2 Score: 0.020618556701030927
# ROUGE-L Score: 0.0606060606060606
# BERTScore: 0.6269819140434265
#
# ------------------------------------------------
#
# Prompt:
# Describe Uocchie in Neapolitan dialect.
#
# Fine-Tuned LLama Response:
# Describe Uocchie in Neapolitan dialect. The Uocchie are a family of fishermen who live in the coastal town of Bari, in the province of Bari, in the region of Apulia, in southern Italy. They are known for their skill in fishing and their strong sense of tradition. They are also known for their unique dialect, which is a combination of Neapolitan dialect and Italian. The Uocchie dialect is a mixture of the local dialect of Bari and
#
# Expected Response:
# Gl uocchie, è gl òrgane de sènz prengepale de gl seštèma visive, ch'adda peglià nfremmaziune ngim’a quéll che seccède tòrn tòrn a iss attraviérz la luce.
# Gl uocchie umane (é de gl erganism seperiure) raccògl la luce che gl arriva de tutt attòrn a iss, ne règula la petènza attraviérz ne diaframma (l'iride), la fecalizza attraviérz ne seštèma regulábbele de lènd pe ne crià ne retratt ngim’a la rètena é gl cagna énd a na sèrie de segnale lèttrece ch’attraviérz gl niérv òtteche viéve mannate a gl cerviégl pe la štésa é la nderpretazione.
#
# BLEU Score: 6.490568812607093e-232
# ROUGE-1 Score: 0.050505050505050504
# ROUGE-2 Score: 0.0
# ROUGE-L Score: 0.050505050505050504
# BERTScore: 0.5446711182594299
#
# ------------------------------------------------
#
# Prompt:
# Describe Rescecature in Neapolitan dialect.
#
# Fine-Tuned LLama Response:
# Describe Rescecature in Neapolitan dialect. How it was used in everyday life and why.
# Describe Rescecature in Neapolitan dialect. How it was used in everyday life and why.
# Describe Rescecature in Neapolitan dialect. How it was used in everyday life and why.
# Rescècatura (plural Rescècature) is a Neapolitan dialect word for the act of saying something in a different way, or in a way that is not normal
#
# Expected Response:
# Gle rescecature (IPA: [rǝʃǝkaˈtuːrǝ], sing.: rescecatore [rǝʃǝkaˈtoːrǝ]; Rodentia Bowdich, 1821) suó gl'òrdene de mammífere che tiéve gle cchiù ávete númmere de spèce mendevate (faštima no comme biomassa), abbraccènne circa gle 43% de tutte le spèce de mammífere ch'esištene a gle juorne d'uoje, cchiù avetetande taxa schembarze. Suó rrescite a avé tutte šte secciése faštima razie a gle fatte ca suó peccerigle, ca ze repredúcene cchiù vòte a gl'anne é a gle fatte ca rriéscene a rescecà é a chenzemà na ròssa varietà de magnà.
# De ss'òrdene fave parte spèce assá chenesciute é da gl'ariale ne muare spase, comm'a ratte, surge é ciurle, é pure spèce rare é da gl'ariale assá reštritte.
# Etemeleggía.
# Gle nome "rescecatore" ne vè da gle vèrbe latine "*rōsĭcare", che ne vè da "rōdĕre" (part. pass. "rōsus") "rescecà", ch'accènna a l'abbetúdene ch'acchemuna tutte gl'agnemale che fave parte de ss'òrdene.
#
# BLEU Score: 2.8122040270770547e-232
# ROUGE-1 Score: 0.03174603174603175
# ROUGE-2 Score: 0.0
# ROUGE-L Score: 0.03174603174603175
# BERTScore: 0.5398423075675964
#
# ------------------------------------------------
