# %% [markdown]
# # Deep Learning and Applied AI (DLAI) Project: **Fine-Tuning a LLM on Neapolitan Dialect**
#
# # Part III: Performance Evaluation
#
# ### Author: Aur Marina Iuliana, 1809715

# %% [markdown]
# # 1. Import Libraries

# %%
# !pip install transformers torch peft datasets evaluate trl bitsandbytes nltk rouge-score bert-score
# Out:
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# gcsfs 2024.10.0 requires fsspec==2024.10.0, but you have fsspec 2024.9.0 which is incompatible.
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import torch
from transformers import AutoModelForCausalLM, AutoTokenizer, pipeline
from transformers import Trainer, TrainingArguments, DataCollatorForLanguageModeling

from trl import SFTConfig, SFTTrainer
from nltk.translate.bleu_score import sentence_bleu
from rouge_score import rouge_scorer
from bert_score import score as bert_score

import numpy as np
import pandas as pd
import os

import matplotlib.pyplot as plt
import seaborn as sns
import json
import glob

from transformers import EarlyStoppingCallback

from datasets import Dataset, load_dataset
from sklearn.model_selection import train_test_split

from tqdm import tqdm
from peft import get_peft_model, LoraConfig, TaskType
import re

import warnings
warnings.simplefilter(action = 'ignore')

# %%
# !huggingface-cli login
# Out:
#     _|    _|  _|    _|    _|_|_|    _|_|_|  _|_|_|  _|      _|    _|_|_|      _|_|_|_|    _|_|      _|_|_|  _|_|_|_|
#     _|    _|  _|    _|  _|        _|          _|    _|_|    _|  _|            _|        _|    _|  _|        _|
#     _|_|_|_|  _|    _|  _|  _|_|  _|  _|_|    _|    _|  _|  _|  _|  _|_|      _|_|_|    _|_|_|_|  _|        _|_|_|
#     _|    _|  _|    _|  _|    _|  _|    _|    _|    _|    _|_|  _|    _|      _|        _|    _|  _|        _|
#     _|    _|    _|_|      _|_|_|    _|_|_|  _|_|_|  _|      _|    _|_|_|      _|        _|    _|    _|_|_|  _|_|_|_|
#
#     To login, `huggingface_hub` requires a token generated from https://huggingface.co/settings/tokens .
# Enter your token (input will not be visible):
# Add token as git credential? (Y/n) n
# Token is valid (permission: read).
# Your token has been saved to /root/.cache/huggingface/token
# Login successful

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
device
# Out:
# device(type='cuda')

# %%
if torch.cuda.is_available():
    gpu_name = torch.cuda.get_device_name(0)
    print("GPU:", gpu_name)
# Out:
# GPU: Tesla T4

# %% [markdown]
# # 2. Import and Split Data

# %%
# Load the dataset and split it into train, validation and test sets:
# 70% of the data will be used for training
# 10% of the data for validation
# 20% of the data for testing

final_dataset = load_dataset('csv', data_files='/content/sample_data/nap_dialect.csv', split = ['train[:70%]', 'train[70%:80%]', 'train[80%:]'])

final_dataset = {
    "train": final_dataset[0],
    "validation": final_dataset[1],
    "test": final_dataset[2]
}

final_dataset
# Out:
# Generating train split: 0 examples [00:00, ? examples/s]
# {'train': Dataset({
#      features: ['recipe', 'prompt', 'content'],
#      num_rows: 8855
#  }),
#  'validation': Dataset({
#      features: ['recipe', 'prompt', 'content'],
#      num_rows: 1265
#  }),
#  'test': Dataset({
#      features: ['recipe', 'prompt', 'content'],
#      num_rows: 2530
#  })}

# %% [markdown]
# # 3. Modelling

# %% [markdown]
# ## 3.1 Vanilla Llama Model

# %%
torch.random.manual_seed(0)
model_name = "meta-llama/Llama-3.2-1B"

vanilla_model = AutoModelForCausalLM.from_pretrained(
    model_name,
    device_map = "auto",
    torch_dtype = "auto",
    trust_remote_code = True,
)

vanilla_tokenizer = AutoTokenizer.from_pretrained(model_name)
vanilla_tokenizer.pad_token = vanilla_tokenizer.eos_token
# Out:
# config.json:   0%|          | 0.00/843 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/2.47G [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/185 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/50.5k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/9.09M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/301 [00:00<?, ?B/s]

# %% [markdown]
# ## 3.2 Fine-Tuned Llama Model

# %%
fine_tuned_model = AutoModelForCausalLM.from_pretrained("/content/drive/MyDrive/DLAI/fine_tuned_LLM_model").to(device)
fine_tuned_tokenizer = AutoTokenizer.from_pretrained("/content/drive/MyDrive/DLAI/fine_tuned_LLM_model")

# %% [markdown]
# # 4. Performance Evaluation

# %% [markdown]
# ## 4.1 Perplexity

# %%
def compute_ppl(model, encodings, max_length = 128, stride = 512, device = "cuda"):
  '''
  Compute the perplexity of a given model using the provided encodings.
  '''
  if max_length is None:
      max_length = model.config.max_length

  seq_len = encodings.input_ids.size(1)
  nlls = []
  prev_end_loc = 0

  for begin_loc in tqdm(range(0, seq_len, stride)):
    end_loc = min(begin_loc + max_length, seq_len)
    trg_len = end_loc - prev_end_loc  # May differ from stride on the last loop
    input_ids = encodings.input_ids[:, begin_loc:end_loc].to(device)
    target_ids = input_ids.clone()
    target_ids[:, :-trg_len] = -100  # Only consider trg_len labels

    with torch.no_grad():
      outputs = model(input_ids, labels=target_ids)

      # Loss is calculated using CrossEntropyLoss which averages over valid labels
      neg_log_likelihood = outputs.loss

      nlls.append(neg_log_likelihood)
      prev_end_loc = end_loc
      if end_loc == seq_len:
        break

  ppl = torch.exp(torch.stack(nlls).mean())
  return ppl

# %%
# Prepare the test data
test_set = final_dataset['test']

vanilla_encodings = vanilla_tokenizer("\n\n".join(test_set["recipe"]), return_tensors = "pt", truncation = True, max_length = 131072).to(device)
fine_tuned_encodings = fine_tuned_tokenizer("\n\n".join(test_set["recipe"]), return_tensors = "pt", truncation = True, max_length = 131072).to(device)

# %%
fine_tuned_ppl = compute_ppl(fine_tuned_model, fine_tuned_encodings)

print(f"Fine-tuned model perplexity: {fine_tuned_ppl}")
# Out:
# 100%|██████████| 256/256 [00:26<00:00,  9.50it/s]
# Fine-tuned model perplexity: 17.342409133911133

# %%
vanilla_ppl = compute_ppl(vanilla_model, vanilla_encodings)

print(f"Vanilla model perplexity: {vanilla_ppl}")
# Out:
# 100%|██████████| 256/256 [00:36<00:00,  7.06it/s]
# Vanilla model perplexity: 36.56854248046875

# %% [markdown]
# ## 4.2 BLEU, ROUGE and BERT Scores

# %%
def compute_scores(generated_responses, reference_texts):
  rouge = rouge_scorer.RougeScorer(['rouge1', 'rouge2', 'rougeL'], use_stemmer=True)
  results = []

  P, R, F1 = bert_score(generated_responses, reference_texts, lang = "it")

  for i, (gen_text, ref_text) in enumerate(zip(generated_responses, reference_texts)):
    # Compute BLEU Score
    bleu_score = sentence_bleu([ref_text.split()], gen_text.split())

    # Compute ROUGE Score
    rouge_scores = rouge.score(ref_text, gen_text)
    rouge1 = rouge_scores['rouge1'].fmeasure
    rouge2 = rouge_scores['rouge2'].fmeasure
    rougeL = rouge_scores['rougeL'].fmeasure

    # BERTScore
    bert_f1 = F1[i].item()

    # Save the results
    results.append({
        "bleu": bleu_score,
        "r1": rouge1,
        "r2": rouge2,
        "rl": rougeL,
        "bertscore": bert_f1
        })

  return results

# %%
def performance_evaluation(model, tokenizer, examples):
  model.generation_config.pad_token_id = tokenizer.pad_token_id

  total_bleu = 0
  total_rouge1 = 0
  total_rouge2 = 0
  total_rougeL = 0
  total_bert_f1 = 0

  num_examples = len(examples)

  for example in examples:
    # Adapt the expected_response to the generated response to ensure consistency
    prompt, expected_response = example['prompt'], example['content'][:150]
    inputs = tokenizer(prompt, return_tensors="pt").to(device)
    output = model.generate(**inputs, max_length = 150)
    response = tokenizer.decode(output[0], skip_special_tokens=True)

    results = compute_scores([response], [expected_response])

    # Accumulate the scores
    total_bleu += results[0]['bleu']
    total_rouge1 += results[0]['r1']
    total_rouge2 += results[0]['r2']
    total_rougeL += results[0]['rl']
    total_bert_f1 += results[0]['bertscore']

  # Compute averages
  avg_bleu = total_bleu / num_examples
  avg_rouge1 = total_rouge1 / num_examples
  avg_rouge2 = total_rouge2 / num_examples
  avg_rougeL = total_rougeL / num_examples
  avg_bert_f1 = total_bert_f1 / num_examples

  return {
        'average_bleu': avg_bleu,
        'average_rouge1': avg_rouge1,
        'average_rouge2': avg_rouge2,
        'average_rougeL': avg_rougeL,
        'average_bert_f1': avg_bert_f1
    }

# %%
# Compute scores using Fine-Tuned Llama Model
examples = final_dataset['test'].select(range(50))

fine_tuned_results = performance_evaluation(fine_tuned_model, fine_tuned_tokenizer, examples)
fine_tuned_results
# Out:
# {'average_bleu': 0.0008286037947656906,
#  'average_rouge1': 0.10212841273170642,
#  'average_rouge2': 0.02026238786883845,
#  'average_rougeL': 0.09816964547565897,
#  'average_bert_f1': 0.5795589756965637}

# %%
# Compute scores using Vanilla Llama Model
vanilla_results = performance_evaluation(vanilla_model, vanilla_tokenizer, examples)
vanilla_results
# Out:
# {'average_bleu': 7.271179166361325e-80,
#  'average_rouge1': 0.04704129930363604,
#  'average_rouge2': 0.012848002241936322,
#  'average_rougeL': 0.04650841446695374,
#  'average_bert_f1': 0.5613727229833603}

# %%
# Build the evaluation Dataframe
fine_tuned_results['perplexity'] = fine_tuned_ppl.item()
vanilla_results['perplexity'] = vanilla_ppl.item()

evaluation_df = pd.DataFrame([fine_tuned_results, vanilla_results], index=['Fine-Tuned Llama Model', 'Vanilla LLama Model'])
evaluation_df = evaluation_df.round(4)
evaluation_df
# Out:
#                         average_bleu  average_rouge1  average_rouge2  \
# Fine-Tuned Llama Model        0.0008          0.1021          0.0203
# Vanilla LLama Model           0.0000          0.0470          0.0128
#
#                         average_rougeL  average_bert_f1  perplexity
# Fine-Tuned Llama Model          0.0982           0.5796     17.3424
# Vanilla LLama Model             0.0465           0.5614     36.5685

# %% [markdown]
# # 5. Qualitative Assessment

# %%
def generate_response(model, tokenizer, examples):
  model.generation_config.pad_token_id = tokenizer.pad_token_id

  total_bleu = 0
  total_rouge1 = 0
  total_rouge2 = 0
  total_rougeL = 0
  total_bert_f1 = 0

  num_examples = len(examples)

  for example in examples:
    # Adapt the expected_response to the generated response to ensure consistency
    prompt, expected_response = example['prompt'], example['content'][:150]
    inputs = tokenizer(prompt, return_tensors="pt").to(device)
    output = model.generate(**inputs, max_length = 150)
    response = tokenizer.decode(output[0], skip_special_tokens=True)

    # Compute_metrics
    results = compute_scores([response], [expected_response])

    print(f'Prompt: \n{prompt}\n')
    print(f'Generated Response: \n{response}\n')
    print(f'Expected Response: \n{expected_response}\n')
    print(f'BLEU Score: {results[0]["bleu"]}')
    print(f'ROUGE-1 Score: {results[0]["r1"]}')
    print(f'ROUGE-2 Score: {results[0]["r2"]}')
    print(f'ROUGE-L Score: {results[0]["rl"]}')
    print(f'BERTScore: {results[0]["bertscore"]}\n')
    print('------------------------------------------------\n')

# %%
examples_2 = final_dataset['test'].select(range(10, 13))

print("--- Qualitative Assessment using Fine-Tuned Llama Model --- \n ")
generate_response(fine_tuned_model, fine_tuned_tokenizer, examples_2)
# Out:
# --- Qualitative Assessment using Fine-Tuned Llama Model ---
#
# Prompt:
# Describe Marco Mengoni in Neapolitan dialect.
#
# Generated Response:
# Describe Marco Mengoni in Neapolitan dialect. Marco Mengoni è nu cantante e attore 'e 22 anni d'età. 'O suo nome è Marco Mengoni. 'A sua carriera è comincia 'e 2006, 'e 'e 'a sua canzone 'o "Vivo e vince". 'A canzone è stata scritta 'o Marco Mengoni e 'e "Nico e Vita". 'A canzone è stata scritta 'o Marco Mengoni e 'e "Nico e Vita". 'A canzone è stata scritta 'o Marco Mengoni e 'e "Nico e Vita". 'A canzone è stata scrit
#
# Expected Response:
# Marco Mengoni (Ronciglione, 25 'e dicembre 1988) è nu cantante italiano. E' addevennuto famuso dint'o 2009, aroppo avè vincuto 'a terza serie 'e X Fac
#
# BLEU Score: 9.920753922066722e-79
# ROUGE-1 Score: 0.17647058823529413
# ROUGE-2 Score: 0.04
# ROUGE-L Score: 0.1568627450980392
# BERTScore: 0.632455587387085
#
# ------------------------------------------------
#
# Prompt:
# ...

# %%
print("--- Qualitative Assessment using Vanilla Model --- \n")
generate_response(vanilla_model, vanilla_tokenizer, examples_2)
# Out:
# --- Qualitative Assessment using Vanilla Model ---
#
# Prompt:
# Describe Marco Mengoni in Neapolitan dialect.
#
# Generated Response:
# Describe Marco Mengoni in Neapolitan dialect. He is a Neapolitan singer-songwriter, actor, and television presenter. He is a Neapolitan singer-songwriter, actor, and television presenter. He is the winner of the 5th edition of the talent show Il Divo in 2009. He is the winner of the 5th edition of the talent show Il Divo in 2009. He has released three studio albums. He has released three studio albums. He has released three studio albums.
# Marco Mengoni was born on 8 February 1989, in Naples, Italy, to a family of Roman Catholic priests. His parents are the Rev. Vincenzo Mengoni and Angela Mengoni
#
# Expected Response:
# Marco Mengoni (Ronciglione, 25 'e dicembre 1988) è nu cantante italiano. E' addevennuto famuso dint'o 2009, aroppo avè vincuto 'a terza serie 'e X Fac
#
# BLEU Score: 1.7607566132313832e-155
# ROUGE-1 Score: 0.062015503875969
# ...
